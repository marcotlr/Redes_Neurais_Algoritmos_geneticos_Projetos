# %% [markdown]
# ## 4.13 A liga ternária mais cara do mundo
#
# #### Objetivo:
# Encontre uma liga de três elementos que tenha o maior custo e o menor
# peso atômico. A liga ternária deve ser da forma x A.y B.z C sendo que x + y + z = 100 g,
# x ≥ 5 g, y ≥ 5 g, z ≥ 5 g e “A”, “B” e “C” são elementos químicos diferentes. Utilize o
# preço dado no exercício anterior e peso atômico dados abaixo [3]. Considere que qualquer
# composto com 3 elementos químicos é chamado de liga
#
#
# **Estratégia**:
# Neste notebook, aplicamos um Algoritmo Genético para resolver o problema de encontrar a “liga ternária mais leve e mais cara do mundo”, em que cada candidato representa três elementos cuja soma de massa é fixada em 100 g.
#
# A estratégia de resolução foi baseada no modelo usado na fera 4.13, todos os mesmos operadores genéticos foram usados, porém com a adequação necessária para considerar o peso atômico.
# Foi necessário incluir neste notebook, um dicionário contendo os pesos atômicos associados a cada elemento.
#
# Na função objetivo, foi calculado o peso atômico total, além do valor total. Com esses 2 valores foi calculado uma razão que é usada como valor de fitness para comparação entre indivíduos.
# Nas funções de cruzamento e mutação, foi necessário atualizar também seus pesos atômicos quando avisa mudança de elemento ou de peso em gramas. Fora disso, foi implementado um Algoritmo genético semelhante ao já usado nas demais feras.

# %%
preco_elemento = {
"H": 1.39,
"He": 24,
"Li": 85.6,
"Be": 857,
"B": 3.68,
"C": 0.122,
"N": 0.14,
"O": 0.154,
"F": 2.16,
"Ne": 240,
"Na": 3.43,
"Mg": 2.32,
"Al": 1.79,
"Si": 1.7,
"P": 2.69,
"S": 0.0926,
"Cl": 0.082,
"Ar": 0.931,
"K": 13.6,
"Ca": 2.35,
"Sc": 3460,
"Ti": 11.7,
"V": 385,
"Cr": 9.4,
"Mn": 1.82,
"Fe": 0.424,
"Co": 32.8,
"Ni": 13.9,
"Cu": 6,
"Zn": 2.55,
"Ga": 148,
"Ge": 1010,
"As": 1.31,
"Se": 21.4,
"Br": 4.39,
"Kr": 290,
"Rb": 15500,
"Sr": 6.68,
"Y": 31,
"Nb": 85.6,
"Mo": 40.1,
"Tc": 100000,
"Ru": 10600,
"Rh": 147000,
"Pd": 49500,
"Ag": 521,
"Cd": 2.73,
"In": 167,
"Sn": 18.7,
"Sb": 5.79,
"Te": 63.5,
"I": 35,
"Xe": 1800,
"Cs": 61800,
"Ba": 0.275,
"La": 4.92,
"Ce": 4.71,
"Pr": 103,
"Nd": 57.5,
"Pm": 460000,
"Sm": 13.9,
"Eu": 31.4,
"Gd": 28.6,
"Tb": 658,
"Dy": 307,
"Ho": 57.1,
"Er": 26.4,
"Tm": 3000,
"Yb": 17.1,
"Lu": 643,
"Hf": 900,
"Ta": 312,
"W": 35.3,
"Re": 4150,
"Os": 12000,
"Ir": 56200,
"Pt": 27800,
"Hg": 30.2,
"Tl": 4200,
"Pb":2,
"Bi": 6.36,
"Po": 49200000000000,
"Ac": 29000000000000,
"Th": 287,
"Pa": 280000,
"U": 101,
"Np": 660000,
"Pu": 6490000,
"Am": 750000,
"Cm": 160000000000,
"Bk": 185000000000,
"Cf": 185000000000,
}



preco_elemento_grama = {chave: valor / 1000 for chave, valor in preco_elemento.items()}


print(preco_elemento_grama)
# Out:
# {'H': 0.00139, 'He': 0.024, 'Li': 0.0856, 'Be': 0.857, 'B': 0.00368, 'C': 0.000122, 'N': 0.00014000000000000001, 'O': 0.000154, 'F': 0.00216, 'Ne': 0.24, 'Na': 0.0034300000000000003, 'Mg': 0.00232, 'Al': 0.0017900000000000001, 'Si': 0.0017, 'P': 0.00269, 'S': 9.26e-05, 'Cl': 8.2e-05, 'Ar': 0.0009310000000000001, 'K': 0.0136, 'Ca': 0.00235, 'Sc': 3.46, 'Ti': 0.011699999999999999, 'V': 0.385, 'Cr': 0.0094, 'Mn': 0.00182, 'Fe': 0.000424, 'Co': 0.032799999999999996, 'Ni': 0.013900000000000001, 'Cu': 0.006, 'Zn': 0.0025499999999999997, 'Ga': 0.148, 'Ge': 1.01, 'As': 0.00131, 'Se': 0.0214, 'Br': 0.00439, 'Kr': 0.29, 'Rb': 15.5, 'Sr': 0.006679999999999999, 'Y': 0.031, 'Nb': 0.0856, 'Mo': 0.040100000000000004, 'Tc': 100.0, 'Ru': 10.6, 'Rh': 147.0, 'Pd': 49.5, 'Ag': 0.521, 'Cd': 0.00273, 'In': 0.167, 'Sn': 0.018699999999999998, 'Sb': 0.00579, 'Te': 0.0635, 'I': 0.035, 'Xe': 1.8, 'Cs': 61.8, 'Ba': 0.000275, 'La': 0.00492, 'Ce': 0.00471, 'Pr': 0.103, 'Nd': 0.0575, 'Pm': 460.0, 'Sm': 0.013900000
# ...

# %%
preco_elemento_grama
# Out:
# {'H': 0.00139,
#  'He': 0.024,
#  'Li': 0.0856,
#  'Be': 0.857,
#  'B': 0.00368,
#  'C': 0.000122,
#  'N': 0.00014000000000000001,
#  'O': 0.000154,
#  'F': 0.00216,
#  'Ne': 0.24,
#  'Na': 0.0034300000000000003,
#  'Mg': 0.00232,
#  'Al': 0.0017900000000000001,
#  'Si': 0.0017,
#  'P': 0.00269,
#  'S': 9.26e-05,
#  'Cl': 8.2e-05,
#  'Ar': 0.0009310000000000001,
#  'K': 0.0136,
#  'Ca': 0.00235,
#  'Sc': 3.46,
#  'Ti': 0.011699999999999999,
#  'V': 0.385,
#  'Cr': 0.0094,
#  'Mn': 0.00182,
#  'Fe': 0.000424,
#  'Co': 0.032799999999999996,
#  'Ni': 0.013900000000000001,
#  'Cu': 0.006,
#  'Zn': 0.0025499999999999997,
#  'Ga': 0.148,
#  'Ge': 1.01,
#  'As': 0.00131,
#  'Se': 0.0214,
#  'Br': 0.00439,
#  'Kr': 0.29,
#  'Rb': 15.5,
#  'Sr': 0.006679999999999999,
#  'Y': 0.031,
#  'Nb': 0.0856,
#  'Mo': 0.040100000000000004,
#  'Tc': 100.0,
#  'Ru': 10.6,
#  'Rh': 147.0,
#  'Pd': 49.5,
#  'Ag': 0.521,
#  'Cd': 0.00273,
#  'In': 0.167,
#  'Sn': 0.018699999999999998,
#  'Sb': 0.00579,
# ...

# %%
# peso atômico em gramas por mol
peso_atomico = {
"H": 1.008,
"He": 4.002602,
"Li": 6.94,
"Be": 9.0121831,
"B": 10.81,
"C": 12.011,
"N": 14.007,
"O": 15.999,
"F": 18.998403163,
"Ne": 20.1797,
"Na": 22.98976928,
"Mg": 24.305,
"Al": 26.9815385,
"Si": 28.085,
"P": 30.973761998,
"S": 32.06,
"Cl": 35.45,
"Ar": 39.948,
"K": 39.0983,
"Ca": 40.078,
"Sc": 44.955908,
"Ti": 47.867,
"V": 50.9415,
"Cr": 51.9961,
"Mn": 54.938044,
"Fe": 55.845,
"Co": 58.933194,
"Ni": 58.6934,
"Cu": 63.546,
"Zn": 65.38,
"Ga": 69.723,
"Ge": 72.63,
"As": 74.921595,
"Se": 78.971,
"Br": 79.904,
"Kr": 83.798,
"Rb"
: 85.4678
,
"Sr"
: 87.62
,
"Y"
: 88.90584
,
"Nb"
: 92.90637
,
"Mo"
: 95.95
,
"Tc"
: 97.90721
,
"Ru"
: 101.07
,
"Rh"
: 102.9055
,
"Pd"
: 106.42
,
"Ag"
: 107.8682
,
"Cd"
: 112.414
,
"In"
: 114.818
,
"Sn"
: 118.71
,
"Sb"
: 121.76
,
"Te"
: 127.6
,
"I"
: 126.90447
,
"Xe"
: 131.293
,
"Cs"
: 132.90545196
,
"Ba"
: 137.327
,
"La"
: 138.90547
,
"Ce"
: 140.116
,
"Pr"
: 140.90766
,
"Nd"
: 144.242
,
"Pm"
: 144.91276
,
"Sm"
: 150.36
,
"Eu"
: 151.964
,
"Gd"
: 157.25
,
"Tb"
: 158.92535
,
"Dy"
: 162.5
,
"Ho"
: 164.93033
,
"Er"
: 167.259
,
"Tm"
: 168.93422
,
"Yb"
: 173.045
,
"Lu"
: 174.9668
,
"Hf"
: 178.49
,
"Ta"
: 180.94788
,
"W"
: 183.84
,
"Re"
: 186.207
,
"Os"
: 190.23
,
"Ir"
: 192.217
,
"Pt"
: 195.084
,
"Hg"
: 200.592
,
"Tl"
: 204.38
,
"Pb"
: 207.2
,
"Bi"
: 208.9804
,
"Po"
: 209.0
,
"Ac"
: 227.0
,
"Th"
: 232.0377
,
"Pa"
: 231.03588
,
"U"
: 238.02891
,
"Np"
: 237.0
,
"Pu"
: 244.0
,

"Am": 243.0,
"Cm": 247.0,
"Bk": 247.0,
"Cf": 251.0,
}

# %%
import random
from pprint import pprint
from functools import partial
from itertools import product

from funcoes_fera_14 import funcao_objetivo_pop_liga as funcao_objetivo
from funcoes_fera_14 import cria_populacao_liga as cria_populacao
from funcoes_fera_14 import selecao_torneio_max as funcao_selecao
from funcoes_fera_14 import mutacao_pesos_liga as mutacao_pesos
from funcoes_fera_14 import mutacao_elementos_liga as mutacao_elementos
from funcoes_fera_14 import cruzamento_uniforme_dicionario as funcao_cruzamento
from funcoes_fera_14 import calcula_liga as calcula_liga

# %%
LIMITE = 100

TAMANHO_POPULACAO = 10
NUM_GERACOES = 1000
CHANCE_DE_CRUZAMENTO = 0.5
CHANCE_DE_MUTACAO = 0.05
TAMANHO_LIGA = 3

# %%
populacao = cria_populacao(TAMANHO_POPULACAO, TAMANHO_LIGA, preco_elemento_grama, peso_atomico)

populacao
# Out:
# [{'Nd': {'Peso': 42, 'Valor': 2.415, 'Peso Atomico': 6058.164},
#   'N': {'Peso': 9, 'Valor': 0.00126, 'Peso Atomico': 126.063},
#   'Ti': {'Peso': 49,
#    'Valor': 0.5732999999999999,
#    'Peso Atomico': 2345.4829999999997}},
#  {'Pm': {'Peso': 6, 'Valor': 2760.0, 'Peso Atomico': 869.47656},
#   'Ir': {'Peso': 57, 'Valor': 3203.4, 'Peso Atomico': 10956.369},
#   'Np': {'Peso': 37, 'Valor': 24420.0, 'Peso Atomico': 8769.0}},
#  {'Mo': {'Peso': 64, 'Valor': 2.5664000000000002, 'Peso Atomico': 6140.8},
#   'Tm': {'Peso': 11, 'Valor': 33.0, 'Peso Atomico': 1858.2764200000001},
#   'Th': {'Peso': 25, 'Valor': 7.175, 'Peso Atomico': 5800.9425}},
#  {'N': {'Peso': 12, 'Valor': 0.00168, 'Peso Atomico': 168.084},
#   'Mg': {'Peso': 36, 'Valor': 0.08352, 'Peso Atomico': 874.98},
#   'Gd': {'Peso': 52, 'Valor': 1.4872, 'Peso Atomico': 8177.0}},
#  {'Cs': {'Peso': 39, 'Valor': 2410.2, 'Peso Atomico': 5183.31262644},
#   'Pb': {'Peso': 38, 'Valor': 0.076, 'Peso Atomico': 7873.599999999999},
# ...

# %%
funcao_objetivo = partial(funcao_objetivo)

# %%
hall_da_fama = []

for n in range(NUM_GERACOES):
    
    # Seleção
    fitness = funcao_objetivo(populacao )        
    selecionados = funcao_selecao(populacao, fitness, 3)
    
    # Cruzamento
    proxima_geracao = []
    for pai, mae in zip(selecionados[::2], selecionados[1::2]):
        individuo1, individuo2 = funcao_cruzamento(pai, mae, CHANCE_DE_CRUZAMENTO, preco_elemento_grama, peso_atomico)
        proxima_geracao.append(individuo1)
        proxima_geracao.append(individuo2)
    
    # Mutação
    mutacao_elementos(populacao, CHANCE_DE_MUTACAO, preco_elemento_grama, peso_atomico)
    mutacao_pesos(populacao, CHANCE_DE_MUTACAO, preco_elemento_grama, peso_atomico)
    
    # Atualização do hall da fama
    fitness = funcao_objetivo(proxima_geracao)
        
    maior_fitness = max(fitness)
    indice = fitness.index(maior_fitness)
    hall_da_fama.append(proxima_geracao[indice])    
    
    # Encerramento
    populacao = proxima_geracao

# %%
# Avaliar fitness de todos os melhores indivíduos
fitness = funcao_objetivo(hall_da_fama)

# Identificar o melhor fitness e o índice correspondente
maior_fitness = max(fitness)
indice_melhor = fitness.index(maior_fitness)

# Recuperar o melhor indivíduo
melhor_individuo = hall_da_fama[indice_melhor]

# Calcular peso e valor total (ou outra métrica)
peso_total, valor_total, peso_atomico_total = calcula_liga(melhor_individuo)

print("Melhor indivíduo:", melhor_individuo)
print(f"Peso total: {peso_total:.2f}")
print(f"Valor total: {valor_total:.2f}")
print(f"Peso atômico total: {peso_atomico_total:.2f}")
# Out:
# Melhor indivíduo: {'La': {'Peso': 6, 'Valor': 0.029519999999999998, 'Peso Atomico': 833.43282}, 'Bk': {'Peso': 87, 'Valor': 2.2968, 'Peso Atomico': 14551.533}, 'Br': {'Peso': 7, 'Valor': 344400000000.0, 'Peso Atomico': 1463.0}}
# Peso total: 100.00
# Valor total: 344400000002.33
# Peso atômico total: 16847.97

# %% [markdown]
# ## Conclusão

# %% [markdown]
# Com os testes feito, o algoritmo identificou uma combinações de três elementos que entregam um valor bom levando em conta o menor peso. É um experimento complicado porque leva em conta 2 análises diferentes, porém conseguimos encontrar ligas que são simultaneamente muito caras e surpreendentemente leves, mostrando que existe um aproximação razoável do valor ótimo, que não é facil de ser obtido.
#
# Além disso, todo esse processo foi significativamente rápido, sem necessidade de longos cálculos ou ajustes complexos. Essa agilidade prova que um método bem direcionado, mesmo em problemas com muitas combinações possíveis, pode trazer resultados práticos sem exigir muito tempo de processamento.
